# %% [markdown]
# # Local Group Halo Properties: Notes

# %% [markdown]
# This notebook will generally follow the same order of topics as the Demo.  However, it will go into more detail on certain topics.

# %% [markdown]
# We approximate the local group distance, radial velocity and proper motion likelihood function by sampling from the posterior distributions for these variables reported in the literature and transforming to kinematic variables in the M31-centric coordinate system.

# %%
import localgroup
import triangle
import sklearn
from sklearn import mixture

# %% [markdown]
# Inside the Likelihood object is a "triplet" object called T, which contains an array of sample local groups, each with kinematic parameters consistent with the observational data. Let's plot these kinematic parameters in a "triangle" figure, to show all their 1 and 2-D marginal distributions.

# %%
L = localgroup.Likelihood()
L.generate(Nsamples=2000)
# Out:
# localgroup/halo.py:132: RuntimeWarning: invalid value encountered in divide
#   self.v_r = (self.x*self.vx + self.y*self.vy + self.z*self.vz)/self.D

# %%
aic, bic = L.test_GaussMM(15)
num_gauss_MM = range(1,16)
plot(num_gauss_MM, aic, label="AIC")
plot(num_gauss_MM, bic, label="BIC")
legend(loc='upper left')
title("Evaluating Gauss MM")
ylabel("Score")
xlabel("Number of Mixture Components")

# %%
gmm = mixture.GMM(5, covariance_type='full')
L.set_PDF(gmm)
L.approximate()
test_data = L.samples[1400:]
logprobs, resps = L.evaluate(test_data)

# %%
means = L.PDF.means_
covars = L.PDF.covars_
print logprobs[:5]
print resps[:5]
# Out:
# [-13.05056295 -15.34058861 -12.45843379 -14.20807067 -13.17532018]
# [[  1.89621872e-02   3.91401196e-02   2.79070179e-02   4.71062464e-02
#     8.66884429e-01]
#  [  4.57195227e-04   1.07146416e-02   8.96969963e-04   5.92414456e-01
#     3.95516737e-01]
#  [  5.79640835e-09   4.92630039e-01   1.34536729e-01   8.03011033e-02
#     2.92532123e-01]
#  [  9.20431940e-11   8.10215639e-01   6.57487207e-02   5.47335835e-04
#     1.23488305e-01]
#  [  5.59682180e-10   7.10341818e-01   3.41789885e-02   1.87792965e-02
#     2.36699897e-01]]

# %%
from scipy.stats import multivariate_normal

# %%
print multivariate_normal.pdf(1, 0, 1)
# Out:
# 0.241970724519

# %%
np.sqrt(2*np.pi)*np.exp(-1**2)
# Out:
# 0.92213700889578909

# %%
hist(logprobs)
# Out:
# (array([   4.,    2.,    1.,    9.,   19.,   38.,   69.,  140.,  185.,  133.]),
#  array([-21.02197759, -20.08911442, -19.15625124, -18.22338807,
#         -17.2905249 , -16.35766173, -15.42479856, -14.49193538,
#         -13.55907221, -12.62620904, -11.69334587]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# The above plot shows the distribution of the log probabilities of each of the test points belonging to the GMM. The GMM should perform well because the test data was included in the training data. The score_samples method in sk-learn does not account for the normalization, which is why the plot is cut off at -12. Some basic experimentation with one-dimensional data is shown below to illustrate this fact:

# %%
from numpy.random import normal
norm_data = normal(0,1,4000) #make some 1D Gaussian data.
hist(norm_data)
# Out:
# (array([    6.,    42.,   228.,   614.,  1068.,  1057.,   670.,   258.,
#            53.,     4.]),
#  array([-3.69540941, -2.9620513 , -2.2286932 , -1.49533509, -0.76197698,
#         -0.02861888,  0.70473923,  1.43809734,  2.17145545,  2.90481355,
#          3.63817166]),
#  <a list of 10 Patch objects>)

# %%
norm_gmm = mixture.GMM(1, covariance_type='full')
norm_gmm.fit(norm_data)
norm_test_data = normal(0,1,1200)
aic, bic = norm_gmm.aic(norm_test_data), norm_gmm.bic(norm_test_data)
print "AIC: ", aic
print "BIC: ", bic
# Out:
# AIC:  3412.9641202
# BIC:  3423.14427387

# %%
norm_log_probs, norm_resps = norm_gmm.score_samples(norm_test_data)
hist(norm_log_probs)
# Out:
# (array([   1.,    0.,    0.,    1.,    3.,    9.,   22.,   62.,  180.,  922.]),
#  array([-8.44136153, -7.68899728, -6.93663303, -6.18426878, -5.43190453,
#         -4.67954028, -3.92717603, -3.17481178, -2.42244753, -1.67008328,
#         -0.91771903]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# The plot above shows the log probability distribution of the test data, where logprobs was calculated using gmm.score_samples(). The data is cut off at -1, when it should go to 0. Below we manually calculate the log probabilities and include the normalization...

# %%
hist(np.log(np.sqrt(2*np.pi)*np.exp(-norm_test_data**2)))
# Out:
# (array([   1.,    0.,    0.,    1.,    3.,    9.,   22.,   62.,  181.,  921.]),
#  array([-14.10413985, -12.60183204, -11.09952423,  -9.59721642,
#          -8.09490861,  -6.5926008 ,  -5.09029299,  -3.58798518,
#          -2.08567737,  -0.58336956,   0.91893825]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# With the normalization taken into account, we can see that the gmm does an excellent job fitting the data.

# %%
figure = L.plot_samples(overlay=True)
# Out:
# Quantiles:
# [(0.16, 0.73365097936217127), (0.5, 0.77418527532268322), (0.84, 0.81379544356562428)]
# Quantiles:
# [(0.16, -105.53481627368163), (0.5, -101.15367033165219), (0.84, -96.482570952876927)]
# Quantiles:
# [(0.16, 37.603417051271066), (0.5, 71.88281145713583), (0.84, 114.20879646132306)]
# Quantiles:
# [(0.16, 0.20000711476341354), (0.5, 0.20668071453760245), (0.84, 0.21501706600616485)]
# Quantiles:
# [(0.16, -270.81406605755382), (0.5, -209.18767679530217), (0.84, -144.63494739807032)]
# Quantiles:
# [(0.16, 94.765040973424419), (0.5, 138.61724555231194), (0.84, 186.70148381937256)]

# %% [markdown]
# The above plot shows a Gaussian Mixture model fitted with Gaussians. The shaded regions show two standard deviations. We want to be able to evaluate the goodness of the fit of the GMM, and ideally use cross validation to pick the number of Gaussians to fit to the data.

# %% [markdown]
# ## Code below this comment was useful for developing the Likelihood.plot_samples method. It may be useful later if modifications are made.

# %%
import itertools

import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture

# %%
n_gaussians = 2
colors = ['g', 'r', 'y']
model = mixture.GMM(n_gaussians, covariance_type='full')
axes = np.reshape(figure.axes, (6,6))
for i in range(6):
    for j in range(6):
        if j < i:
            #data = [[L.samples[k,j], L.samples[k,i]] for k in range(len(L.samples[:,0]))]
            #model.fit(data)
            model.fit(L.samples)
            subplot = axes[i,j]
            for gauss_num in range(n_gaussians):
                mean = [model.means_[gauss_num][j], model.means_[gauss_num][i]]
                covar = model.covars_[gauss_num]
                covar = [[covar[j,j], covar[j,i]], [covar[i,j], covar[i,i]]]
                color = colors[gauss_num]
                v, w = linalg.eigh(covar)
                u = w[0]/linalg.norm(w[0])
                angle = np.arctan(u[1]/u[0])
                angle = 180 * angle / np.pi
                ell = mpl.patches.Ellipse(mean, 2*np.sqrt(v[0]), 2*np.sqrt(v[1]), 180 + angle, color=color)
                ell.set_clip_box(subplot.bbox)
                ell.set_alpha(0.5)
                subplot.add_artist(ell)
figure

# %%
model = mixture.GMM(2,covariance_type='full')
#new = [[L.samples[i,1], L.samples[i,3]] for i in range(len(L.samples[:,0]))]
new = L.samples
model.fit(new)

#model = mixture.DPGMM(n_components=2, covariance_type='full')
#model.fit(new)

def eigsorted(cov):
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    return vals[order], vecs[:,order]

splot = figure.axes[30]
mean = [model.means_[0][0], model.means_[0][5]]
covar = model.covars_[0]
covar = [[covar[0,0], covar[0,5]],[covar[5,0], covar[5,5]]]
print "Covariance Matrix: "
print covar
print "Means: "
print model.means_
color = "b"

v, w = linalg.eigh(covar)
#v, w = eigsorted(covar)
u = w[0] / linalg.norm(w[0])

angle = np.arctan(u[1] / u[0])
angle = 180 * angle / np.pi  # convert to degrees
ell = mpl.patches.Ellipse(mean, 2*np.sqrt(v[0]), 2*np.sqrt(v[1]), 180 + angle, color=color)
ell.set_clip_box(splot.bbox)
ell.set_alpha(0.5)
splot.add_artist(ell)
figure
# Out:
# Covariance Matrix:
# [[0.0023878970497562815, -0.84323525479375405], [-0.84323525479375405, 1318.6563843143811]]
# Means:
# [[  7.62149681e-01  -1.01320147e+02   5.35757687e+01   2.08173656e-01
#    -1.67844296e+02   1.47487466e+02]
#  [  7.85070345e-01  -1.00442591e+02   9.09299432e+01   2.06975301e-01
#    -2.44288648e+02   1.31679332e+02]]

# %%
print "Mean: ", mean
print "Covariance Matrix: ", covar
print "Angle: ", angle
print "eig values: ", v[0],v[1]
# Out:
# Mean:  [-98.635885081524407, 0.2072918493050219]
# Covariance Matrix:  [[  1.43247346e+01  -1.18266947e-03]
#  [ -1.18266947e-03   1.07418058e-03]]
# Angle:  89.9952692282
# eig values:  0.00107408292924 14.3247346951

# %%
import numpy as np
import sys
sys.path.append('/afs/slac.stanford.edu/u/ki/yymao/scripts')
from readHlist import readHlist

# idMW idM31 idM33 Mvir x y z vx vy vz

# %%
path = '/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/data_files/complete_triplets.txt'
npoints = 100
halo_props = ['MW_Mvir', 'M31_Mvir', 'M33_Mvir']

# %%
Tr = localgroup.Triplet()

# %%
Tr.read_sim_points(path, npoints, halo_props)
# Out:
# localgroup/halo.py:132: RuntimeWarning: invalid value encountered in divide
#   self.v_r = (self.x*self.vx + self.y*self.vy + self.z*self.vz)/self.D
