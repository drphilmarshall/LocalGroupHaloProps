# %% [markdown]
# # Local Group Halo Properties: Demo Inference

# %% [markdown]
# We approximate the local group distance, radial velocity and proper motion likelihood function by sampling from the posterior distributions for these variables reported in the literature and transforming to kinematic variables in the M31-centric coordinate system.

# %%
import localgroup
import triangle
import sklearn
from sklearn import mixture
import numpy as np
import pickle
import matplotlib.patches as mpatches

# %% [markdown]
# Inside the Likelihood object is a "triplet" object called T, which contains an array of sample local groups, each with kinematic parameters consistent with the observational data. Let's plot these kinematic parameters in a "triangle" figure, to show all their 1 and 2-D marginal distributions.

# %%
L = localgroup.Likelihood(isPair=False)
L.generate(Nsamples=50000)
# Out:
# Inside method: heliocentric_equatorial_spherical_to_galactocentric_cartesian
# l =  [ 121.17440269  121.17440269  121.17440269 ...,  121.17440269  121.17440269
#   121.17440269]
# b =  [-21.57299867 -21.57299867 -21.57299867 ..., -21.57299867 -21.57299867
#  -21.57299867]
# v_west:  125.338893 +/- 30.712439
# v_north: -73.774489 +/- 28.370383
# xh, yh, zh, vxh, vyh, vzh =  [-0.3659269  -0.37247997 -0.36743716 ..., -0.34167716 -0.35585889
#  -0.37561731] [ 0.60482678  0.6156581   0.60732304 ...,  0.56474531  0.58818575
#   0.6208437 ] [-0.27949911 -0.28450442 -0.28065267 ..., -0.26097689 -0.27180905
#  -0.28690076] [ 101.05431132   59.40042928   58.20924849 ...,   70.03154571    7.28535301
#    75.44790583] [-309.78623162 -327.76569753 -314.47931065 ..., -319.71364808 -358.94077564
#  -310.8599576 ] [ 16.51714095  32.21434242  60.10252579 ...,  34.78073299  30.88905721
#   41.0481678 ]
# Inside method: heliocentric_equatorial_spherical_to_galactocentric_cartesian
# l =
# ...

# %% [markdown]
# We will use a Gaussian Mixture Model to fit the sample Triplets drawn from the observational data. The number of Gaussian components will be a parameter that we need to choose, possibly using cross validation. Below we try from 1 to 15 components and plot the AIC and BIC scores (lower is better).

# %%
def aic_scorefn(GMM, X): return GMM.aic(X)
def bic_scorefn(GMM, X): return GMM.bic(X)

# %%
score_dict = L.test_GaussMM(num_folds=10, score_fns=[aic_scorefn, bic_scorefn], maxMM=15)

# %%
bic = score_dict['bic_scorefn']
aic = score_dict['aic_scorefn']
num_gauss_MM = range(1,16)
plot(num_gauss_MM, aic, label="AIC")
plot(num_gauss_MM, bic, label="BIC")
legend(loc='upper left')
title("Evaluating Gauss MM")
ylabel("Score")
xlabel("Number of Mixture Components")

# %% [markdown]
# The above plot shows the AIC and BIC scores as a function of the number of components in the GMM. Note that since we are using the GMM to model the underlying PDF of the data, then we do not care about overfitting. In fact, overfitting is good for us. Therefore we will use more than the "optimal" number of components. In general it is idea to minimize the AIC and BIC. The BIC score is calculated using k-fold cross validation. Currently 10 folds are hard coded into the method, but this can be experimented with.

# %%
L.set_PDF(mixture.GMM(n_components=10, covariance_type='full'))
L.approximate()

# %%
figure_obs = L.plot_samples(10, color='b', overlay=False)
# Out:
# Quantiles:
# [(0.16, 0.7348561309448477), (0.5, 0.77426342748327959), (0.84, 0.81342867399232388)]
# Quantiles:
# [(0.16, -113.46390803265776), (0.5, -109.09894450292222), (0.84, -104.71188668115667)]
# Quantiles:
# [(0.16, 18.845348688714232), (0.5, 37.614239907970664), (0.84, 60.900955903863327)]
# Quantiles:
# [(0.16, 0.19994101688576371), (0.5, 0.20622066748987528), (0.84, 0.21467334366646584)]
# Quantiles:
# [(0.16, -182.8408804758071), (0.5, -135.88542304150744), (0.84, -88.993518871381724)]
# Quantiles:
# [(0.16, 93.158870958375189), (0.5, 124.21665963666118), (0.84, 156.27300520790422)]

# %% [markdown]
# The above plot shows a Gaussian Mixture model fitted Gaussians. The shaded regions show two standard deviations. The samples data has been preprocessed to zero the mean and scale by standard deviation. Since we are using the Gaussian Mixture Model to model the underlying PDF of the data, more components is always better.

# %% [markdown]
# # How to evaluate goodness of fit:

# %% [markdown]
# Due to lack of a standard goodness of fit test for GMM's, the best we can do is graphically show that the model reproduces the data well. We proceed by drawing a set of points from the fitted model, where each point is a local group with (MW_D, MW_vr, MW_vt, M33_D, M33_vr, M33_vt). We then plot the 1D and 2D marginalizations of the drawn point set and show that the marginalizations match the marginalizations of the true data.

# %%
figure_model = L.model_gof(L.T.Nsamples, color="r", fig=None)
# Out:
# Quantiles:
# [(0.16, 0.73448673419830368), (0.5, 0.77448051309906496), (0.84, 0.81417661324639834)]
# Quantiles:
# [(0.16, -113.41564742114237), (0.5, -109.10828900539087), (0.84, -104.74823432260345)]
# Quantiles:
# [(0.16, 19.758520082416798), (0.5, 38.470768059084612), (0.84, 60.834322779605628)]
# Quantiles:
# [(0.16, 0.1999777508421024), (0.5, 0.20641207380889826), (0.84, 0.21481700254206521)]
# Quantiles:
# [(0.16, -182.83508652039879), (0.5, -136.35817205753693), (0.84, -89.295628376196547)]
# Quantiles:
# [(0.16, 92.702206422887201), (0.5, 123.75643810264053), (0.84, 156.46439202702192)]

# %%
L.model_gof(L.T.Nsamples, color="r", fig=figure_obs)
red_patch = mpatches.Patch(color='red')
blue_patch = mpatches.Patch(color='blue')
figure_obs.legend(handles=[red_patch, blue_patch], labels=["Model Generated", "Observation Generated"])
# Out:
# Quantiles:
# [(0.16, 0.73432736082466121), (0.5, 0.77393267852597103), (0.84, 0.81395781900877129)]
# Quantiles:
# [(0.16, -113.42856211924143), (0.5, -109.07067922231789), (0.84, -104.74138365033093)]
# Quantiles:
# [(0.16, 19.905999952640641), (0.5, 38.542697654939516), (0.84, 60.936408850509011)]
# Quantiles:
# [(0.16, 0.19985777407573208), (0.5, 0.20636458614814607), (0.84, 0.21487491501140557)]
# Quantiles:
# [(0.16, -183.05092374501083), (0.5, -136.06632206714858), (0.84, -88.672749451452887)]
# Quantiles:
# [(0.16, 92.85929750590617), (0.5, 124.29882931634853), (0.84, 156.68348126488797)]

# %%
figure_obs

# %% [markdown]
# The above plot shows that the points drawn from the model create a population that is very similar to the true data.

# %%
#figure_obs.savefig("/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/LocalGroupHaloProps/doc/thesis/plots/model_gof.png")

# %% [markdown]
# # Reading Simulation Points:

# %% [markdown]
# Below we read the preconfigured files containing the Consuelo (soon to be Dark Sky) Local Group analogs into a Triplet object. We plot the marginalizations of the simulation data, which allows us to compare with the LG prior.

# %%
path = '/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/data_files/complete_triplets.txt'
npoints = 122000
halo_props = ['MW_Mvir', 'M31_Mvir', 'M33_Mvir']

# %%
Tr = localgroup.Triplet(isPair=False)
Tr.read_sim_points(path, npoints, halo_props)

# %%
Tr.transform_to_M31(sim=True)

# %%
subplot(1,2,1)
hist(Tr.sim_samples[:,0])
title("MW Consuelo D distribution")
subplot(1,2,2)
hist(Tr.sim_samples[:,3])
title("M33 Consuelo D distribution")

# %%
# Filters out the Triplets where the halos are near the edge of the box.
# The periodic BC's make the pair satisfy the conditions, but it's a pain
# to check for that all the time. This filter does not significantly reduce
# the size of our sim samples.
print "sim_sample length before: ",Tr.sim_samples.shape
filter_condition = (Tr.sim_samples[:,0] < 15) & (Tr.sim_samples[:,3] < 15)
#filter_condition = (Tr.sim_samples[:,0] < 15)
Tr.MW.Mvir = Tr.MW.Mvir[filter_condition]
Tr.M31.Mvir = Tr.M31.Mvir[filter_condition]
Tr.M33.Mvir = Tr.M33.Mvir[filter_condition]
Tr.sim_samples = Tr.sim_samples[filter_condition]
print "sim_sample length after: ",Tr.sim_samples.shape
# Out:
# sim_sample length before:  (122000, 6)
# sim_sample length after:  (119851, 6)

# %%
subplot(1,2,1)
hist(Tr.sim_samples[:,0])
title("MW Consuelo D distribution")
subplot(1,2,2)
hist(Tr.sim_samples[:,3])
title("M33 Consuelo D distribution")

# %%
print "max MW D = ", max(Tr.sim_samples[:,3])
print "max M33 D = ", max(Tr.sim_samples[:,0])

print "0.450398090582, 1.17453522591"
# Out:
# max MW D =  0.451004434568
# max M33 D =  1.17454487458
# 0.450398090582, 1.17453522591

# %%
Tr.preprocess(L.samples_means, L.samples_stds, mode='sim')

# %%
sim_plot = Tr.plot_kinematics(Tr.sim_samples, 'sim', L.samples_means, L.samples_stds, color='c', fig=None)
# Out:
# Quantiles:
# [(0.16, -5.7263510528431985), (0.5, 1.6142548857802799), (0.84, 7.5359032190915132)]
# Quantiles:
# [(0.16, -10.134493884068917), (0.5, 6.4397482324158322), (0.84, 19.029157043780806)]
# Quantiles:
# [(0.16, -0.65349568470474495), (0.5, 0.95168943300090714), (0.84, 3.9305082621598935)]
# Quantiles:
# [(0.16, -4.7781865813733706), (0.5, 9.3231795117099363), (0.84, 21.787815830580911)]
# Quantiles:
# [(0.16, 0.1274544111999194), (0.5, 1.7054918608292615), (0.84, 3.7202032025810983)]
# Quantiles:
# [(0.16, -2.496746676677847), (0.5, -0.86033373322334961), (0.84, 1.6230434413390646)]

# %%
Tr.sim_samples.shape
# Out:
# (119851, 6)

# %%
Tr.M31.Mvir.shape
# Out:
# (119851,)

# %%
dat = np.transpose(np.vstack((np.transpose(Tr.sim_samples), Tr.M31.Mvir, Tr.MW.Mvir, Tr.M33.Mvir)))

# %%
dat[:,0:6].shape
# Out:
# (119851, 6)

# %%
Tr.GMM(20, dat)

# %%
Tr.GMM_sample(500000)

# %%
weights = np.transpose(np.exp(L.evaluate(Tr.gmm_samples[:,0:6])[0]))
Tr.weights = weights
#N95 = Tr.calculate_N95()
#print "N95 = ",N95
total = Tr.gmm_samples[:,6] + Tr.gmm_samples[:,7]
all_mvir = np.log10(np.transpose(np.vstack((Tr.gmm_samples[:,7], Tr.gmm_samples[:,6], total))))
labs = ["MWMvir", "M31Mvir", "MW+M31"]
figure = triangle.corner(all_mvir, labels=labs, quantiles=[0.16,0.5,0.84], fig=None, weights=None,\
                         plot_contours=True, show_titles=True, title_args={"fontsize": 12}, \
                         plot_datapoints=False, bins=20, color='red')
# Out:
# Quantiles:
# [(0.16, 11.548022680266504), (0.5, 11.929842495178006), (0.84, 12.42701436195996)]
# Quantiles:
# [(0.16, 11.546873319049787), (0.5, 11.975991384050568), (0.84, 12.464421479410426)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-ada2d9d8f7cc> in <module>()
#       6 all_mvir = np.log10(np.transpose(np.vstack((Tr.gmm_samples[:,7], Tr.gmm_samples[:,6], total))))
#       7 labs = ["MWMvir", "M31Mvir", "MW+M31"]
# ----> 8 figure = triangle.corner(all_mvir, labels=labs, quantiles=[0.16,0.5,0.84], fig=None, weights=None,                         plot_contours=True, show_titles=True, title_args={"fontsize": 12},                          plot_datapoints=False, bins=20, color='red')
#
# ...

# %%
labels = ["$D^{\\rm MW}$", "$v_{\\rm rad}^{\\rm MW}$", "$v_{\\rm tan}^{\\rm MW}$", "$D^{\\rm M33}$", "$v_{\\rm rad}^{\\rm M33}$", "$v_{\\rm tan}^{\\rm M33}$"]
figure = triangle.corner(dat[:,0:6], labels=labels, quantiles=[0.16,0.5,0.84], fig=None, show_titles=True, title_args={"fontsize": 12}, color='c')
# Out:
# Quantiles:
# [(0.16, -5.7263510528431985), (0.5, 1.6142548857802799), (0.84, 7.5359032190915132)]
# Quantiles:
# [(0.16, -10.134493884068917), (0.5, 6.4397482324158322), (0.84, 19.029157043780806)]
# Quantiles:
# [(0.16, -0.65349568470474495), (0.5, 0.95168943300090714), (0.84, 3.9305082621598935)]
# Quantiles:
# [(0.16, -4.7781865813733706), (0.5, 9.3231795117099363), (0.84, 21.787815830580911)]
# Quantiles:
# [(0.16, 0.1274544111999194), (0.5, 1.7054918608292615), (0.84, 3.7202032025810983)]
# Quantiles:
# [(0.16, -2.496746676677847), (0.5, -0.86033373322334961), (0.84, 1.6230434413390646)]

# %%
pl = Tr.plot_kinematics(Tr.gmm_samples, 'gmm', L.samples_means, L.samples_stds, color='b', fig=None)
# Out:
# Quantiles:
# [(0.16, -5.504466801691386), (0.5, 1.5130384401158599), (0.84, 7.4919110369638284)]
# Quantiles:
# [(0.16, -10.042558904416451), (0.5, 6.4548695275148402), (0.84, 18.935824930704449)]
# Quantiles:
# [(0.16, -0.62529022054823735), (0.5, 0.96021077604869121), (0.84, 3.9258449118686611)]
# Quantiles:
# [(0.16, -4.0979290328667997), (0.5, 8.8057414664242835), (0.84, 21.34787005861001)]
# Quantiles:
# [(0.16, 0.1100469441000574), (0.5, 1.6802926055460614), (0.84, 3.7724845492255858)]
# Quantiles:
# [(0.16, -2.4626173459681491), (0.5, -0.81495177585873901), (0.84, 1.6716303279360125)]

# %%
pl

# %%
Tr.plot_kinematics(L.samples_means, L.samples_stds, color='g', fig=figure_model)
# Out:
# Quantiles:
# [(0.16, 0.54455210953589972), (0.5, 0.83849209894904275), (0.84, 1.0756675136858633)]
# Quantiles:
# [(0.16, -153.50573509321492), (0.5, -80.658698620422285), (0.84, -25.324294038838428)]
# Quantiles:
# [(0.16, 26.27769824136967), (0.5, 59.756071749045454), (0.84, 121.91435793834177)]

# %%
red_patch = mpatches.Patch(color='red')
green_patch = mpatches.Patch(color='green')
figure_model.legend(handles=[red_patch, green_patch], labels=["Model Generated", "Consuelo Triplets"])
figure_model

# %%
#figure_model.savefig("/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/LocalGroupHaloProps/doc/thesis/plots/sim_plot.png")

# %%
Tr.compute_model_weights(L)

# %%
N95 = Tr.calculate_N95()
N95
# Out:
# 2074

# %%
total = Tr.MW.Mvir + Tr.M31.Mvir
all_mvir = np.log10(np.transpose(np.vstack((Tr.MW.Mvir, Tr.M31.Mvir, total))))
labs = ["MWMvir", "M31Mvir", "MW+M31"]

# %%
all_mvir.shape
# Out:
# (120642, 3)

# %%
figure = triangle.corner(all_mvir, labels=labs, quantiles=[0.16,0.5,0.84], fig=figure_res, weights=np.transpose(Tr.weights),\
                         plot_contours=True, show_titles=True, title_args={"fontsize": 12}, \
                         plot_datapoints=False, bins=20, color='red')
# Out:
# Quantiles:
# [(0.16, 11.585909456579897), (0.5, 11.818481906679796), (0.84, 12.108788201860234)]
# Quantiles:
# [(0.16, 11.557881183728497), (0.5, 11.977775260402531), (0.84, 12.218535505216527)]
# Quantiles:
# [(0.16, 12.008471993398343), (0.5, 12.106974776227686), (0.84, 12.468149341545365)]

# %%
red_patch = mpatches.Patch(color='red')
blue_patch = mpatches.Patch(color='blue')
figure_res.legend(handles=[red_patch, blue_patch], labels=["Triplets using M33 dynamics", "Pairs assuming M33 existence"])
figure_res

# %%
#figure_res.savefig("/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/LocalGroupHaloProps/doc/thesis/plots/res_plot.png")

# %%
figure_res = triangle.corner(all_mvir, labels=labs, quantiles=[0.16,0.5,0.84], weights=np.transpose(Tr.weights),\
                         plot_contours=True, show_titles=True, title_args={"fontsize": 12}, \
                         plot_datapoints=False, bins=20, color='blue')
# Out:
# Quantiles:
# [(0.16, 11.623446746089458), (0.5, 11.936749424017886), (0.84, 12.230321168919078)]
# Quantiles:
# [(0.16, 11.647654808142605), (0.5, 12.020833445458141), (0.84, 12.302607957426817)]
# Quantiles:
# [(0.16, 12.06303071129956), (0.5, 12.348713647467754), (0.84, 12.518157145463164)]

# %%
Tr.weights.shape
# Out:
# (120645,)

# %%
xdata = total
plot(xdata, Tr.weights)
xscale('log')

# %%
bins = 20
xbins = np.logspace(np.log10(xdata.min()), np.log10(xdata.max()), bins)
ybins = [np.sum(Tr.weights[(xdata[:]>xbins[i]) & (xdata[:]<xbins[i+1])]) for i in range(bins-1)]
print len(xbins)
print len(ybins)
print len(xbins[:bins-1])
# Out:
# 20
# 19
# 19

# %%
plot(xbins[:bins-1], ybins)
xscale('log')

# %%
xtrip = np.copy(xbins[:bins-1])
ytrip = np.copy(ybins)

# %%
xtripmw = np.copy(xbins[:bins-1])
ytripmw = np.copy(ybins)

# %%
xpairmw = np.copy(xbins[:bins-1])
ypairmw = np.copy(ybins)

# %%
xpair = np.copy(xbins[:bins-1])
ypair = np.copy(ybins)

# %%
plot(xtripmw, ytripmw, color='r')
plot(xpairmw, ypairmw, color='b')
ylabel('P(MMW)')
xlabel('MMW')

red_patch = mpatches.Patch(color='red')
blue_patch = mpatches.Patch(color='blue')
legend(["Trips, M33 dynamics", "Pairs, M33 existence"])
xscale('log')
#savefig("/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/LocalGroupHaloProps/doc/thesis/plots/pdf_mw_plot.png")

# %%
legend?

# %%
np.logspace?

# %% [markdown]
# # Triangle Plotting Experimentation

# %%
labs = ["MWD", "MWvr", "MWvt", "M33D", "M33vr", "M33vt"]

# %%
figure = triangle.corner(Tr.sim_samples, labels=labs, quantiles=[0.16,0.5,0.84], \
                         plot_contours=True, show_titles=True, title_args={"fontsize": 12}, \
                         plot_datapoints=False, bins=20, color='blue')
# Out:
# Quantiles:
# [(0.16, -5.7226828671443002), (0.5, 1.6400202687990817), (0.84, 7.541690091421267)]
# Quantiles:
# [(0.16, -10.075904354697036), (0.5, 6.2426499793695793), (0.84, 18.917184734931542)]
# Quantiles:
# [(0.16, -0.65816706822910132), (0.5, 0.95263210133194798), (0.84, 3.9946885206005671)]
# Quantiles:
# [(0.16, -4.6849186985061007), (0.5, 9.5306119067133306), (0.84, 21.845285344331309)]
# Quantiles:
# [(0.16, 0.15577634016068292), (0.5, 1.7097811715110651), (0.84, 3.6857156249942125)]
# Quantiles:
# [(0.16, -2.4902007607585293), (0.5, -0.85682802692364812), (0.84, 1.6268137616355249)]

# %%
x = Tr.sim_samples[:,0]
y = Tr.sim_samples[:,3]
xbins = np.arange(x.min(), x.max(), .25)
ybins = np.arange(y.min(), y.max(), .25)
imp = None
smooth=True
color = 'r'
style = 'shaded'

# %%
from pappy.plotting import pdf2d

# %%
fi, axs = subplots(2,2)
axis = axs[0,0]

# %%
axs = figure.get_axes()

# %%
axis = axs[0]

# %%
ax = pdf2d(axis,x,y,imp, xbins, ybins, smooth, color, style)

# %%
figure

# %%
ax = pdf2d(axis,x,y,imp, xbins, ybins, smooth, color, style)

# %%
fi

# %%
axis

# %%
ax.get_figure?

# %%
figure.set_axes?

# %%
ax2=gca()

# %%
from pylab import histogram2d

# %%
ax2.hist2d?

# %%
histogram2d?

# %%
gcf()

# %%
triangle.hist2dnew(x,y,xbins = np.arange(x.min(), x.max(), .25), ax=axis, ybins = np.arange(y.min(), y.max(), .25), imp = None, smooth=True, color = 'r', style = 'shaded')

# %%
fi

# %%
a = np.ndarray((3,3))

# %%
a.flatten?

# %%
np.arange?
