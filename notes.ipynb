# %% [markdown]
# # Local Group Halo Properties: Demo Inference

# %%
import localgroup
import triangle
import sklearn
from sklearn import mixture

# %% [markdown]
# We approximate the local group distance, radial velocity and proper motion likelihood function by sampling from the posterior distributions for these variables reported in the literature and transforming to kinematic variables in the M31-centric coordinate system.

# %%
L = localgroup.Likelihood()
L.generate(Nsamples=4000)
# Out:
# localgroup/halo.py:132: RuntimeWarning: invalid value encountered in divide
#   self.v_r = (self.x*self.vx + self.y*self.vy + self.z*self.vz)/self.D

# %% [markdown]
# Inside the Likelihood object is a "triplet" object called T, which contains an array of sample local groups, each with kinematic parameters consistent with the observational data. Let's plot these kinematic parameters in a "triangle" figure, to show all their 1 and 2-D marginal distributions.

# %% [markdown]
# The above plot shows a Gaussian Mixture model fitted with two Gaussians. The shaded regions show two standard deviations. We want to be able to evaluate the goodness of the fit of the GMM, and ideally use cross validation to pick the number of Gaussians to fit to the data.

# %%
aic, bic = L.test_GaussMM(15)
num_gauss_MM = range(1,16)
plot(num_gauss_MM, aic, label="AIC")
plot(num_gauss_MM, bic, label="BIC")
legend(loc='upper left')
title("Evaluating Gauss MM")
ylabel("Score")
xlabel("Number of Mixture Components")

# %%
gmm = mixture.GMM(5, covariance_type='full')
L.set_PDF(gmm)
L.approximate()
test_data = L.samples[2800:]
print test_data
logprobs = L.evaluate(test_data)
# Out:
# [[  7.16876312e-01  -1.03562839e+02   5.34180395e+01   2.02270054e-01
#    -1.97834429e+02   2.01079400e+02]
#  [  8.64622581e-01  -1.02809008e+02   6.01898542e+01   2.20265160e-01
#    -2.52032806e+02   6.10652281e+01]
#  [  8.17871045e-01  -1.01601763e+02   5.24894982e+01   2.08041528e-01
#    -2.61198855e+02   8.47950120e+01]
#  ...,
#  [  7.77884085e-01  -1.03213580e+02   9.46156226e+01   2.04760499e-01
#    -2.36035999e+02   1.32105255e+02]
#  [  7.52916502e-01  -9.83614674e+01   6.38862115e+01   2.12547590e-01
#    -2.05569670e+02   2.03182206e+02]
#  [  7.91339504e-01  -1.04886489e+02   5.12752214e+01   2.00900148e-01
#    -2.13000837e+02   1.09308096e+02]]
# [[  7.16876312e-01  -1.03562839e+02   5.34180395e+01   2.02270054e-01
#    -1.97834429e+02   2.01079400e+02]
#  [  8.64622581e-01  -1.02809008e+02   6.01898542e+01   2.20265160e-01
#    -2.52032806e+02   6.10652281e+01]
#  [  8.17871045e-01  -1.01601763e+02   5.24894982e+01   2.08041528e-01
# ...

# %%
figure = L.plot_samples(overlay=True)
# Out:
# Quantiles:
# [(0.16, 0.73379791162169594), (0.5, 0.77367368738651998), (0.84, 0.81163889460864813)]
# Quantiles:
# [(0.16, -105.22655119992277), (0.5, -100.91170476540947), (0.84, -96.522073389018885)]
# Quantiles:
# [(0.16, 36.89693427015564), (0.5, 71.828462237315307), (0.84, 113.71235437325905)]
# Quantiles:
# [(0.16, 0.19995476461005082), (0.5, 0.2060276423665201), (0.84, 0.21471229516702556)]
# Quantiles:
# [(0.16, -271.1959202194443), (0.5, -207.64453304888545), (0.84, -145.33040690566796)]
# Quantiles:
# [(0.16, 93.2184920482742), (0.5, 139.58872327026279), (0.84, 184.88555167208651)]

# %%
from numpy.random import normal

norm_data = normal(0,1,4000)
hist(norm_data)
# Out:
# (array([    2.,    12.,    86.,   388.,   904.,  1237.,   894.,   398.,
#            68.,    11.]),
#  array([-4.36007119, -3.56473572, -2.76940024, -1.97406476, -1.17872929,
#         -0.38339381,  0.41194167,  1.20727714,  2.00261262,  2.7979481 ,
#          3.59328357]),
#  <a list of 10 Patch objects>)

# %%
norm_gmm = mixture.GMM(1, covariance_type='full')
norm_gmm.fit(norm_data)
norm_test_data = normal(0,1,1200)
aic, bic = norm_gmm.aic(norm_test_data), norm_gmm.bic(norm_test_data)
print "AIC: ", aic
print "BIC: ", bic
# Out:
# AIC:  3350.80692148
# BIC:  3360.98707515

# %%
norm_log_probs, norm_resps = norm_gmm.score_samples(norm_test_data)
hist(norm_log_probs)
# Out:
# (array([   1.,    2.,    2.,    2.,    8.,   12.,   32.,   59.,  169.,  913.]),
#  array([-7.29797006, -6.660898  , -6.02382594, -5.38675389, -4.74968183,
#         -4.11260977, -3.47553772, -2.83846566, -2.2013936 , -1.56432155,
#         -0.92724949]),
#  <a list of 10 Patch objects>)

# %%
hist(np.log(np.sqrt(np.pi)*np.exp(-norm_test_data**2)))
# Out:
# (array([   1.,    2.,    2.,    3.,    7.,   12.,   32.,   58.,  169.,  914.]),
#  array([-12.43486562, -11.13414256,  -9.83341951,  -8.53269645,
#          -7.23197339,  -5.93125034,  -4.63052728,  -3.32980423,
#          -2.02908117,  -0.72835812,   0.57236494]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Here begins the confusion:  I tested the goodness of the GMM mixture model on the actual data in L.samples, and it seemed like the GMM model did a terrible job.  I was surprised at how badly it seemed to be performing, so I decided to do some simple examples to make sure that I wasn't messing up the application of the GMM.  These are the tales of my struggles...
#
#
# In the cell below, I choose to consider only the MW_D component of the L.samples data.  As you can see from the plot above, this data is well described by a single Gaussian.  I train a GMM with one Gaussian component on the first 700 samples out of a total of 1000 samples.  I test the trained model on the remaining 300 data points.  I print the BIC score; low BIC is apparently good, but since it isn't normalized, I have no idea what the numbers mean.  That can be dealt with later.

# %%
data = L.samples[:,0]
gmm = mixture.GMM(1, covariance_type='full')
train = data[:700]
gmm.fit(train)
test = data[700:]
probs = gmm.score_samples(test)
print "BIC: ", gmm.bic(test)
gmm.score_samples([.9,.75])
# Out:
# BIC:  -1000.64335557
# (array([-0.97343322,  1.02817802]), array([[ 1.],
#         [ 1.]]))

# %% [markdown]
# According to the GMM documentation on scikit-learn: http://scikit-learn.org/stable/modules/generated/sklearn.mixture.GMM.html#sklearn.mixture.GMM.fit, probs is an array that contains the log probability of the data points under the model gmm.  That means that each entry in probs[0] is a log probability of that test point belonging to the GMM trained on the training data.  The problem becomes evident:  The log probabilities should by definition be negative, but somehow they are not!  Am I misunderstanding the scikit-learn documentation? Something is not right, and I don't know what.  I do more investigation to see whether the gmm trained on the above data actually does a good job of predicting the distribution...

# %%
probs[0][:40]
# Out:
# array([ 0.25651638,  1.90545449,  0.47611886,  2.02974591,  1.71524137,
#         1.87937139,  1.84714095,  2.02886268,  1.98251373,  2.0044455 ,
#         1.9945354 ,  1.99580919,  1.61204515,  0.22283027,  2.02540193,
#         2.04258107,  1.99781225,  2.046519  ,  1.63144267,  2.04796641,
#         2.03729731,  1.9177222 ,  2.04275706,  1.48022628,  1.72465644,
#         1.92110264,  2.02896616,  1.46033621,  0.86880669,  1.95857993,
#         2.04791135,  1.97763843,  1.96655848,  2.04278667,  2.00328515,
#         1.51766745,  1.94234929,  2.04769182,  1.95948434,  1.8772917 ])

# %% [markdown]
# Below I plot three histograms. The blue plot is a histogram of the entire data set, so all of L.samples[:,0].  It matches the corresponding subplot in the above triangle plot, so no surprise there. The green plot is a histogram of new data generated from the gmm model. It shows that the gmm model does a good job reproducing the true distribution!  The red plot shows the data points that were tested to make sure that the test points do not have a funky distribution by accident. Clearly they dont.

# %%
hist(data)
hist(gmm.sample(700))
hist(test)
gmm.score_samples([1.5,.75])
# Out:
# (array([-97.60068532,   1.9437505 ]), array([[ 1.],
#         [ 1.]]))

# %% [markdown]
# Conclusion:  The gmm model trained to predict MW_D does a good job of reproducing the true distribution, at least qualitatively.
#
# Problem:  I have no idea how to interpret the "log probabilities" returned by the scikit-learn method score.
#
# Below:  I do a similar test, but instead of using L.samples to train a GMM model, I draw from a Gaussian distribution to guarantee that the data is Gaussian.  I have the same problem.
#
# Question:  Am I doing something stupid? Is scikit-learn doing something stupid? I am checking the actual implementation of the mixture.GMM class, the code for which is found on github:
#
# https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/mixture/gmm.py
#
# to try to figure out what exactly they are doing.

# %%
norm_data = np.random.normal(0.77,0.03,500)
hist(norm_data)
model = mixture.GMM(1, covariance_type='full')
model.fit(norm_data)

# %%
norm_test_data = np.random.normal(0.77,.03,30)
model.score(norm_test_data)
# Out:
# array([ 2.10311881,  2.0141955 ,  2.06429897,  2.18271748,  0.83870121,
#         1.49451751,  1.72644227,  2.20335757,  2.20100581,  1.97429112,
#         2.20304811,  2.13196357,  2.20294477,  2.20357939,  1.14182357,
#         2.16785566,  2.2011075 ,  1.30151556,  1.3412341 ,  2.20688209,
#         0.60557784,  2.19188277,  2.19028729,  1.99906022,  1.11866512,
#         2.09692146,  2.20686236,  1.15479359,  2.20742249,  2.1956094 ])

# %%
norm_test_data
# Out:
# array([ 0.75671986,  0.72857479,  0.73018067,  0.79911609,  0.77139484,
#         0.7506875 ,  0.80697494,  0.78825206,  0.77181584,  0.76546282,
#         0.77328649,  0.80904913,  0.82023216,  0.78522422,  0.75444014,
#         0.77247317,  0.79293961,  0.73564647,  0.74180057,  0.73400807,
#         0.79045091,  0.78643256,  0.78510097,  0.75885636,  0.73929703,
#         0.78680378,  0.78576028,  0.71776896,  0.75072638,  0.78730511])

# %%
L.set_PDF(mixture.GMM(10, covariance_type='full'))
train_data = L.samples[:4500]
test_data = L.samples[4500:]
L.PDF.fit(train_data)
a=L.PDF.score_samples(test_data)
b=L.PDF.predict_proba(test_data)
a2 = L.PDF.score_samples(train_data[0:100])
print "BIC score: ", L.PDF.bic(test_data)
print "AIC score: ", L.PDF.aic(test_data)
# Out:
# BIC score:  15599.3984072
# AIC score:  14423.5227478

# %%
print b[0:5]
print a[1][0:5]
a2
# Out:
# [[ 0.76971564  0.23028436]
#  [ 0.00834355  0.99165645]
#  [ 0.79606768  0.20393232]
#  [ 0.03275626  0.96724374]
#  [ 0.222188    0.777812  ]]
# [[ 0.76971564  0.23028436]
#  [ 0.00834355  0.99165645]
#  [ 0.79606768  0.20393232]
#  [ 0.03275626  0.96724374]
#  [ 0.222188    0.777812  ]]
# (array([-14.53036146, -14.1356099 , -15.54707632, -13.73814593,
#         -11.83502167, -16.04263502, -13.36565729, -13.00365134,
#         -13.17725911, -12.64842808, -12.58450878, -13.87926356,
#         -12.15632333, -14.3726112 , -12.73759892, -12.144746  ,
#         -14.89604661, -14.41889682, -13.15820893, -13.47118961,
#         -12.61629545, -13.51068454, -12.384889  , -12.9690782 ,
#         -12.53528599, -12.58616201, -12.27372739, -13.11093324,
#         -20.15258378, -14.30858158, -12.72781973, -13.10855857,
#         -16.72501986, -15.74125387, -15.44765368, -13.24119546,
#         -15.07737507, -12.99562973, -14.99483979, -14.09344738,
# ...

# %% [markdown]
# ## Code below this comment was useful for developing the Likelihood.plot_samples method. It may be useful later if modifications are made.

# %%
import itertools

import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture

# %%
n_gaussians = 2
colors = ['g', 'r', 'y']
model = mixture.GMM(n_gaussians, covariance_type='full')
axes = np.reshape(figure.axes, (6,6))
for i in range(6):
    for j in range(6):
        if j < i:
            #data = [[L.samples[k,j], L.samples[k,i]] for k in range(len(L.samples[:,0]))]
            #model.fit(data)
            model.fit(L.samples)
            subplot = axes[i,j]
            for gauss_num in range(n_gaussians):
                mean = [model.means_[gauss_num][j], model.means_[gauss_num][i]]
                covar = model.covars_[gauss_num]
                covar = [[covar[j,j], covar[j,i]], [covar[i,j], covar[i,i]]]
                color = colors[gauss_num]
                v, w = linalg.eigh(covar)
                u = w[0]/linalg.norm(w[0])
                angle = np.arctan(u[1]/u[0])
                angle = 180 * angle / np.pi
                ell = mpl.patches.Ellipse(mean, 2*np.sqrt(v[0]), 2*np.sqrt(v[1]), 180 + angle, color=color)
                ell.set_clip_box(subplot.bbox)
                ell.set_alpha(0.5)
                subplot.add_artist(ell)
figure

# %%
model = mixture.GMM(2,covariance_type='full')
#new = [[L.samples[i,1], L.samples[i,3]] for i in range(len(L.samples[:,0]))]
new = L.samples
model.fit(new)

#model = mixture.DPGMM(n_components=2, covariance_type='full')
#model.fit(new)

def eigsorted(cov):
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    return vals[order], vecs[:,order]

splot = figure.axes[30]
mean = [model.means_[0][0], model.means_[0][5]]
covar = model.covars_[0]
covar = [[covar[0,0], covar[0,5]],[covar[5,0], covar[5,5]]]
print "Covariance Matrix: "
print covar
print "Means: "
print model.means_
color = "b"

v, w = linalg.eigh(covar)
#v, w = eigsorted(covar)
u = w[0] / linalg.norm(w[0])

angle = np.arctan(u[1] / u[0])
angle = 180 * angle / np.pi  # convert to degrees
ell = mpl.patches.Ellipse(mean, 2*np.sqrt(v[0]), 2*np.sqrt(v[1]), 180 + angle, color=color)
ell.set_clip_box(splot.bbox)
ell.set_alpha(0.5)
splot.add_artist(ell)
figure
# Out:
# Covariance Matrix:
# [[0.0023878970497562815, -0.84323525479375405], [-0.84323525479375405, 1318.6563843143811]]
# Means:
# [[  7.62149681e-01  -1.01320147e+02   5.35757687e+01   2.08173656e-01
#    -1.67844296e+02   1.47487466e+02]
#  [  7.85070345e-01  -1.00442591e+02   9.09299432e+01   2.06975301e-01
#    -2.44288648e+02   1.31679332e+02]]

# %%
print "Mean: ", mean
print "Covariance Matrix: ", covar
print "Angle: ", angle
print "eig values: ", v[0],v[1]
# Out:
# Mean:  [-98.635885081524407, 0.2072918493050219]
# Covariance Matrix:  [[  1.43247346e+01  -1.18266947e-03]
#  [ -1.18266947e-03   1.07418058e-03]]
# Angle:  89.9952692282
# eig values:  0.00107408292924 14.3247346951
