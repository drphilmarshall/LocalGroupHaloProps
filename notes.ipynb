# %% [markdown]
# # Local Group Halo Properties: Demo Inference

# %% [markdown]
# We approximate the local group distance, radial velocity and proper motion likelihood function by sampling from the posterior distributions for these variables reported in the literature and transforming to kinematic variables in the M31-centric coordinate system.

# %%
import localgroup
import triangle
import sklearn
from sklearn import mixture
import numpy as np
import pickle

# %% [markdown]
# Inside the Likelihood object is a "triplet" object called T, which contains an array of sample local groups, each with kinematic parameters consistent with the observational data. Let's plot these kinematic parameters in a "triangle" figure, to show all their 1 and 2-D marginal distributions.

# %%
L = localgroup.Likelihood(isPair=False)
L.generate(Nsamples=50000)
# Out:
# Inside method: heliocentric_equatorial_spherical_to_galactocentric_cartesian
# l =  [ 121.17440269  121.17440269  121.17440269 ...,  121.17440269  121.17440269
#   121.17440269]
# b =  [-21.57299867 -21.57299867 -21.57299867 ..., -21.57299867 -21.57299867
#  -21.57299867]
# v_west:  125.386411 +/- 30.897917
# v_north: -73.755796 +/- 28.538355
# xh, yh, zh, vxh, vyh, vzh =  [-0.38404953 -0.36812554 -0.35545002 ..., -0.33579709 -0.35036603
#  -0.36306503] [ 0.63478099  0.60846082  0.58750995 ...,  0.55502635  0.57910681
#   0.6000965 ] [-0.29334138 -0.28117845 -0.27149675 ..., -0.25648562 -0.26761354
#  -0.27731318] [  69.96662153   48.60062034    8.17580332 ...,  102.35972473   47.22855679
#    34.97106471] [-320.88675596 -314.51226984 -362.21569088 ..., -294.82498893 -348.50626194
#  -314.07151553] [ 33.92004584  78.86373489  21.4002523  ...,  46.2927577    3.65001698
#   92.99486444]
# Inside method: heliocentric_equatorial_spherical_to_galactocentric_cartesian
# l =
#  [ 133.61015002  133.61015002  133.61015002 ...,  133.61015002  133.61015002
#   133.61015002]
# b =  [-31.33063998 -31.33063998 -31.33063998 ..., -31.33063998 -31.33063998
#  -31.33063998]
# v_west:  87.916028 +/- 25.969026
# v_north: 28.112529 +/- 33.508015
# xh, yh, zh, vxh, vyh, vzh =  [-0.4802841  -0.4593273  -0.47762829 ..., -0.4811694  -0.46125127
#  -0.47420885] [ 0.50416912  0.48217011  0.50138123 ...,  0.50509845  0.48418976
#   0.49779174] [-0.42387842 -0.40538283 -0.42153451 ..., -0.42465974 -0.40708084
#  -0.41851666] [ 35.38501287  19.13240125 -17.67083239 ...,  43.50027813  52.40048953
#    9.98529384] [-150.97692884 -136.07955021 -217.47077051 ..., -132.00628215 -205.33748804
#  -160.09378401] [ 128.00671024  163.98319256  109.8083306  ...,  141.12800154   42.57145881
#   146.36049435]

# %% [markdown]
# We will use a Gaussian Mixture Model to fit the sample Triplets drawn from the observational data. The number of Gaussian components will be a parameter that we need to choose, possibly using cross validation. Below we try from 1 to 15 components and plot the AIC and BIC scores (lower is better).

# %%
def aic_scorefn(GMM, X): return GMM.aic(X)
def bic_scorefn(GMM, X): return GMM.bic(X)

# %%
score_dict = L.test_GaussMM(num_folds=10, score_fns=[aic_scorefn, bic_scorefn], maxMM=15)

# %%
bic = score_dict['bic_scorefn']
aic = score_dict['aic_scorefn']
num_gauss_MM = range(1,16)
plot(num_gauss_MM, aic, label="AIC")
plot(num_gauss_MM, bic, label="BIC")
legend(loc='upper left')
title("Evaluating Gauss MM")
ylabel("Score")
xlabel("Number of Mixture Components")

# %% [markdown]
# The above plot shows the AIC and BIC scores as a function of the number of components in the GMM. Note that since we are using the GMM to model the underlying PDF of the data, then we do not care about overfitting. In fact, overfitting is good for us. Therefore we will use more than the "optimal" number of components. In general it is idea to minimize the AIC and BIC. The BIC score is calculated using k-fold cross validation. Currently 10 folds are hard coded into the method, but this can be experimented with.

# %%
L.set_PDF(mixture.GMM(n_components=10, covariance_type='full'))
L.approximate()

# %%
figure = L.plot_samples(10, overlay=True)
# Out:
# Quantiles:
# [(0.16, -0.99442906937115283), (0.5, 0.0056315318433220341), (0.84, 0.99168262742773705)]
# Quantiles:
# [(0.16, -0.9945578541677258), (0.5, -0.00070626151191505659), (0.84, 0.9941125268463763)]
# Quantiles:
# [(0.16, -1.0134956186029891), (0.5, -0.11275843292763399), (0.84, 1.0062942916067807)]
# Quantiles:
# [(0.16, -0.8723376774849898), (0.5, -0.15250432122440397), (0.84, 0.82396077531593659)]
# Quantiles:
# [(0.16, -1.0067510636800567), (0.5, -0.0059618331238206652), (0.84, 1.0067037817346018)]
# Quantiles:
# [(0.16, -0.95849520293161183), (0.5, -0.0063688616471703399), (0.84, 0.97243963766563479)]

# %% [markdown]
# The above plot shows a Gaussian Mixture model fitted Gaussians. The shaded regions show two standard deviations. The samples data has been preprocessed to zero the mean and scale by standard deviation. Since we are using the Gaussian Mixture Model to model the underlying PDF of the data, more components is always better.

# %% [markdown]
# # How to evaluate goodness of fit:

# %% [markdown]
# Due to lack of a standard goodness of fit test for GMM's, the best we can do is graphically show that the model reproduces the data well. We proceed by drawing a set of points from the fitted model, where each point is a local group with (MW_D, MW_vr, MW_vt, M33_D, M33_vr, M33_vt). We then plot the 1D and 2D marginalizations of the drawn point set and show that the marginalizations match the marginalizations of the true data.

# %%
gof_figure = L.model_gof(L.T.Nsamples)
# Out:
# Quantiles:
# [(0.16, -1.0076933024674637), (0.5, 0.0043910650065373535), (0.84, 0.98813918419560631)]
# Quantiles:
# [(0.16, -0.99664926846180035), (0.5, -0.00085030624729687254), (0.84, 0.99062368049540106)]
# Quantiles:
# [(0.16, -1.0209453431361089), (0.5, -0.1234750552410849), (0.84, 1.0017943138589789)]

# %% [markdown]
# The above plot shows that the points drawn from the model create a population that is very similar to the true data.

# %% [markdown]
# # Reading Simulation Points:

# %% [markdown]
# Below we read the preconfigured files containing the Consuelo (soon to be Dark Sky) Local Group analogs into a Triplet object. We plot the marginalizations of the simulation data, which allows us to compare with the LG prior.

# %%
path = '/afs/slac.stanford.edu/u/ki/mwillia1/Thesis/data_files/complete_triplets.txt'
npoints = 10000
halo_props = ['MW_Mvir', 'M31_Mvir', 'M33_Mvir']

# %%
Tr = localgroup.Triplet(isPair=False)
Tr.read_sim_points(path, npoints, halo_props)

# %%
Tr.transform_to_M31(sim=True)

# %%
subplot(1,2,1)
hist(Tr.sim_samples[:,0])
title("MW Consuelo D distribution")
subplot(1,2,2)
hist(Tr.sim_samples[:,3])
title("M33 Consuelo D distribution")

# %%
# Filters out the Triplets where the halos are near the edge of the box.
# The periodic BC's make the pair satisfy the conditions, but it's a pain
# to check for that all the time. This filter does not significantly reduce
# the size of our sim samples.
print "sim_sample length before: ",Tr.sim_samples.shape
filter_condition = (Tr.sim_samples[:,0] < 15) & (Tr.sim_samples[:,3] < 15)
#filter_condition = (Tr.sim_samples[:,0] < 15)
Tr.MW.Mvir = Tr.MW.Mvir[filter_condition]
Tr.M31.Mvir = Tr.M31.Mvir[filter_condition]
Tr.M33.Mvir = Tr.M33.Mvir[filter_condition]
Tr.sim_samples = Tr.sim_samples[filter_condition]
print "sim_sample length after: ",Tr.sim_samples.shape
# Out:
# sim_sample length before:  (10000, 6)
# sim_sample length after:  (9832, 6)

# %%
subplot(1,2,1)
hist(Tr.sim_samples[:,0])
title("MW Consuelo D distribution")
subplot(1,2,2)
hist(Tr.sim_samples[:,3])
title("M33 Consuelo D distribution")

# %%
print "max MW D = ", max(Tr.sim_samples[:,3])
print "max M33 D = ", max(Tr.sim_samples[:,0])

print "0.450398090582, 1.17453522591"
# Out:
# max MW D =  0.450398090582
# max M33 D =  1.1741895077
# 0.450398090582, 1.17453522591

# %%
Tr.preprocess(L.samples_means, L.samples_stds)
sim_plot = Tr.tri_plot()
# Out:
# Quantiles:
# [(0.16, -5.782987579262703), (0.5, 1.7187864943130133), (0.84, 7.4678851579791221)]
# Quantiles:
# [(0.16, -10.012087925572938), (0.5, 6.6291127974912412), (0.84, 19.078452480143511)]
# Quantiles:
# [(0.16, -0.69578673666086066), (0.5, 0.95676862603924406), (0.84, 3.883406619293666)]
# Quantiles:
# [(0.16, -5.0783775798489748), (0.5, 9.1637492551718047), (0.84, 21.651406833907135)]
# Quantiles:
# [(0.16, 0.1584380413945142), (0.5, 1.7274522945171298), (0.84, 3.7569556071000161)]
# Quantiles:
# [(0.16, -2.4819875010663792), (0.5, -0.89519467866238811), (0.84, 1.5887900923752687)]

# %%
logprobs, resps = L.evaluate(Tr.sim_samples)

# %%
logprobs2 = logprobs[logprobs[:] > -10000]

# %%
hist(logprobs2)
# Out:
# (array([ 1126.,  1155.,  1107.,  1051.,   977.,   946.,   755.,   480.,
#           243.,    43.]),
#  array([-9999.52084939, -9018.02907644, -8036.53730348, -7055.04553052,
#         -6073.55375757, -5092.06198461, -4110.57021166, -3129.0784387 ,
#         -2147.58666574, -1166.09489279,  -184.60311983]),
#  <a list of 10 Patch objects>)

# %%
Tr.compute_model_weights(L)

# %%
N95 = Tr.calculate_N95()
N95
# Out:
# 5

# %%
hist(Tr.weights)
# Out:
# (array([  9.83000000e+03,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([ 0.        ,  0.07186971,  0.14373942,  0.21560913,  0.28747884,
#          0.35934855,  0.43121826,  0.50308798,  0.57495769,  0.6468274 ,
#          0.71869711]),
#  <a list of 10 Patch objects>)

# %%
w = Tr.weights[Tr.weights[:] > .01]

# %%
np.sum(w)
# Out:
# 0.92662699446117025

# %%
total = Tr.MW.Mvir + Tr.M31.Mvir
all_mvir = np.log10(np.transpose(np.vstack((Tr.MW.Mvir, Tr.M31.Mvir, total))))
labs = ["MW_Mvir", "M31_Mvir", "MW+M31"]

# %%
all_mvir.shape
# Out:
# (9832, 3)

# %%
figure = triangle.corner(all_mvir, labels=labs, quantiles=[0.16,0.5,0.84], weights=np.transpose(Tr.weights),\
                         plot_contours=True, show_titles=True, title_args={"fontsize": 12}, \
                         plot_datapoints=False, bins=20, color='blue')
# Out:
# Quantiles:
# [(0.16, 12.062828320089936), (0.5, 12.416730987124927), (0.84, 12.416941100739699)]
# Quantiles:
# [(0.16, 11.992213194543586), (0.5, 11.992213194543586), (0.84, 11.992213194543586)]
# Quantiles:
# [(0.16, 12.386588046737193), (0.5, 12.555622636487772), (0.84, 12.555622750808418)]

# %%
Tr.weights.shape
# Out:
# (1964,)

# %%
hist(Tr.weights)
# Out:
# (array([  1.81100000e+03,   1.18000000e+02,   1.30000000e+01,
#           1.30000000e+01,   2.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   2.00000000e+00,   1.00000000e+00,
#           2.00000000e+00]),
#  array([  8.01907298e-06,   9.59048037e-04,   1.91007700e-03,
#           2.86110597e-03,   3.81213493e-03,   4.76316389e-03,
#           5.71419286e-03,   6.66522182e-03,   7.61625079e-03,
#           8.56727975e-03,   9.51830872e-03]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Triangle Plotting Experimentation

# %%
labs = ["MW_D", "MW_vr", "MW_vt", "M33_D", "M33_vr", "M33_vt"]

# %%
figure = triangle.corner(Tr.sim_samples, labels=labs, quantiles=[0.16,0.5,0.84], \
                         plot_contours=True, show_titles=True, title_args={"fontsize": 12}, \
                         plot_datapoints=False, bins=20, color='blue')
# Out:
# Quantiles:
# [(0.16, -5.9244482898843653), (0.5, 1.1518302959155109), (0.84, 7.1622732740618185)]
# Quantiles:
# [(0.16, -10.204421145445096), (0.5, 6.3544358984045992), (0.84, 18.556484342961628)]
# Quantiles:
# [(0.16, -1.0335368070939202), (0.5, 0.10482095676402248), (0.84, 2.0922339350006363)]
# Quantiles:
# [(0.16, -5.1529069157281722), (0.5, 8.7251544773194656), (0.84, 21.246674945517462)]
# Quantiles:
# [(0.16, 0.091008287117265163), (0.5, 1.3124226252814444), (0.84, 2.8833764589149706)]
# Quantiles:
# [(0.16, -2.3928520293071354), (0.5, -0.87112916177657529), (0.84, 1.2836285404879118)]

# %%
x = Tr.sim_samples[:,2]
y = Tr.sim_samples[:,5]
xbins = np.arange(x.min(), x.max(), .25)
ybins = np.arange(y.min(), y.max(), .25)
imp = None
smooth=True
color = 'r'
style = 'shaded'

# %%
import matplotlib.pylab as pylab
import numpy as numpy

# %%
def pdf2d2(axis,ax,ay,imp,xbins,ybins,smooth,color,style,conditional=False):

  from scipy import ndimage

  axis.xlim([xbins[0],xbins[-1]])
  axis.ylim([ybins[0],ybins[-1]])

  # npts = int((ax.size/4)**0.5)
  H,x,y = numpy.histogram2d(ax,ay,weights=imp,bins=[xbins,ybins])
  
  totalmass = sum(H.flatten())
  H = ndimage.gaussian_filter(H,smooth)

  norm = numpy.sum(H.flatten())
  H = H * (norm > 0.0) / (norm + (norm == 0.0))
  
  sortH = numpy.sort(H.flatten())
  cumH = sortH.cumsum()
  # 1, 2, 3-sigma, for the old school:
  lvl00 = 2*sortH.max()
  lvl68 = sortH[cumH>cumH.max()*0.32].min()
  lvl95 = sortH[cumH>cumH.max()*0.05].min()
  lvl997 = sortH[cumH>cumH.max()*0.003].min()

#   print "2D histogram: min,max = ",H.min(),H.max()
#   print "Contour levels: ",[lvl00,lvl68,lvl95,lvl997]

  if style == 'shaded':

    # Plot shaded areas first:
    axis.contourf(H.T,[lvl997,lvl95],colors=color,alpha=0.1,\
                   extent=(xbins[0],xbins[-1],ybins[0],ybins[-1]))
    axis.contourf(H.T,[lvl95,lvl68],colors=color,alpha=0.4,\
                   extent=(xbins[0],xbins[-1],ybins[0],ybins[-1]))
    axis.contourf(H.T,[lvl68,lvl00],colors=color,alpha=0.7,\
                   extent=(xbins[0],xbins[-1],ybins[0],ybins[-1]))
  # endif

  # Always plot outlines:
  axis.contour(H.T,[lvl68,lvl95,lvl997],colors=color,\
                  extent=(xbins[0],xbins[-1],ybins[0],ybins[-1]))
#   pylab.contour(H.T,[lvl68,lvl95],colors=color,\
#                   extent=(xbins[0],xbins[-1],ybins[0],ybins[-1]))

  return gca()

# %%
ax = pdf2d2(x,y,imp, xbins, ybins, smooth, color, style)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-4c930ef4a75e> in <module>()
# ----> 1 ax = pdf2d2(figure.axes[2],x,y,imp, xbins, ybins, smooth, color, style)
#
# <ipython-input-42-b95f345d75c2> in pdf2d2(axis, ax, ay, imp, xbins, ybins, smooth, color, style, conditional)
#       3   from scipy import ndimage
#       4
# ----> 5   axis.xlim([xbins[0],xbins[-1]])
#       6   axis.ylim([ybins[0],ybins[-1]])
#       7
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlim'

# %%
color = 'b'
ax2 = pdf2d2(x,y,imp, xbins, ybins, smooth, color, style, ax)

# %%
a = -1*np.array([1,2,5,3,7,6,9,2,1,2])
a
# Out:
# array([-1, -2, -5, -3, -7, -6, -9, -2, -1, -2])

# %%
a.sort()

# %%
a
# Out:
# array([-9, -7, -6, -5, -3, -2, -2, -2, -1, -1])

# %%
a[::-1]
# Out:
# array([9, 7, 6, 5, 3, 2, 2, 2, 1, 1])

# %%
np.random.normal?

# %%
x = np.random.normal(66, 27, 100000)
y = np.random.normal(-76, 19, 100000)
z = np.random.normal(45, 27, 100000)
v = np.sqrt(x**2 + y**2 + z**2)

print 'mean = ', np.mean(v)
print 'std = ', np.std(v)
# Out:
# mean =  116.050739405
# std =  22.9377320593

# %%
import numpy as np
from sdfpy import load_sdf, SDFIndex

bn = "/nfs/slac/g/ki/darksky/simulations/ds14_b/" 
hn = bn + "ds14_b_halos_1.0000"
mn = hn + ".midx7"


halos_data = load_sdf(hn)
halos_midx = load_sdf(mn)
halos = SDFIndex(halos_data, halos_midx)

left = [0.0, 0.0, 0.0]
right= [20.0, 20.0, 20.0]

for c in halos.iter_bbox_data(left, right, ['x','y','z','m200b']):
    print c['m200b'].size
# Out:
# 21632
# 792
# 544
# 2452
# 1006
# 3729
# 172
# 142
# 3226
# 1081
# 1416
# 993
# 61

# %%
data = halos.iter_bbox_data?

# %%
data = halos.iter_bbox_data(left, right, ['x','y','z','m200b'])

# %%
data.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-8689352af601> in <module>()
# ----> 1 data.keys()
#
# AttributeError: 'generator' object has no attribute 'keys'

# %%
halos.iter_data?
